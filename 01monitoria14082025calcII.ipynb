# %% [markdown]
# <a href="https://colab.research.google.com/github/marianayoshioka/mytools/blob/main/01monitoria14082025calcII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import symbols,sin,cos,pi
from sympy.plotting import plot,plot3d_parametric_surface,plot_parametric,plot3d_parametric_line

# %%
# !pip install sympy

# %%
x = symbols('x')
plot(sin(x), (x, -pi, pi), title='Plot of sine')

# %%
x = symbols('x')
plot(x, x**2, x**3, (x, -2, 2), title="Plot of many graphs")
