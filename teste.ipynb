# %% [markdown]
# <a href="https://colab.research.google.com/github/marianayoshioka/mytools/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
print("I'm in love")
# Out:
# Hello, World!
# I'm in love

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')
plot(x**2, (x, -5, 5), title='Plot of x^2')

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')
plot(x, x**2, x**3, (x, -2, 2), legend=True)
